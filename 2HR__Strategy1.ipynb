# %% [markdown]
# <a href="https://colab.research.google.com/github/Amlan05/EquityMeanReversion/blob/main/2HR__Strategy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas-ta
# Out:
# Requirement already satisfied: pandas-ta in /usr/local/lib/python3.11/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandas-ta) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.17.0)

# %%
import pandas as pd
import pandas_ta as ta
import matplotlib.pyplot as plt
import numpy as np

# %%
file_path = '/content/RELI 2HR.csv'

# %%
data = pd.read_csv(file_path, parse_dates=['Date'], dayfirst=True)

# %%
data.rename(columns={'close': 'Close', 'high': 'High', 'open': 'Open', 'low': 'Low'}, inplace=True)

# %%
def convert_volume(volume):
    if isinstance(volume, str):
        if 'K' in volume:
            return float(volume.replace('K', '').replace(',', '')) * 1_000
        elif 'M' in volume:
            return float(volume.replace('M', '').replace(',', '')) * 1_000_000
        else:
            return float(volume.replace(',', ''))
    return volume

# Apply the conversion
data['Volume'] = data['Volume'].apply(convert_volume)

# %%
data = data.sort_values(by='Date').reset_index(drop=True)

# %%
print(data.tail())
# Out:
#                            Date     Open     High      Low   Close   Volume
# 5019  2025-01-24T15:00:00+05:30  1246.10  1248.00  1243.50  1246.3  1776011
# 5020  2025-01-27T09:00:00+05:30  1239.10  1240.45  1220.00  1220.4  3317612
# 5021  2025-01-27T11:00:00+05:30  1220.50  1233.50  1220.00  1230.8  3039450
# 5022  2025-01-27T13:00:00+05:30  1230.80  1235.90  1225.00  1230.0  2343373
# 5023  2025-01-27T15:00:00+05:30  1230.15  1231.65  1227.85  1229.0   789840

# %%
# Calculate Support and Resistance
data['Support'] = data['Low'][data['Low'] == data['Low'].rolling(window=9, center=True).min()]
data['Resistance'] = data['High'][data['High'] == data['High'].rolling(window=9, center=True).max()]

# Fill missing values with the previous value (forward-fill)
data['Support'] = data['Support'].ffill()
data['Resistance'] = data['Resistance'].ffill()

# %%
# RSI with SMA
data['RSI'] = ta.rsi(data['Close'], length=14, mamode="sma")

# %%
# MACD
macd_data = ta.macd(data['Close'], fast=12, slow=26, signal=9, append=True)
data['MACD_Histogram'] = macd_data['MACDh_12_26_9']

# %%
# ATR
data['ATR'] = ta.atr(data['High'], data['Low'], data['Close'], length=14)

# %%
# Bollinger Bands
bollinger = ta.bbands(data['Close'], length=20, std=2)
data['Upper_BB'] = bollinger['BBU_20_2.0']
data['Lower_BB'] = bollinger['BBL_20_2.0']
data['Middle_BB'] = bollinger['BBM_20_2.0']

# %%
# Moving Averages
data['100_MA'] = ta.sma(data['Close'], length=100)
data['50_MA'] = ta.sma(data['Close'], length=50)
data['20_MA'] = ta.sma(data['Close'], length=20)

# %%
# Rolling Volume Mean
data['Rolling_Volume_Mean'] = data['Volume'].rolling(window=10).mean()

# %%
data.tail()
# Out:
#                            Date     Open     High      Low   Close   Volume  \
# 5019  2025-01-24T15:00:00+05:30  1246.10  1248.00  1243.50  1246.3  1776011
# 5020  2025-01-27T09:00:00+05:30  1239.10  1240.45  1220.00  1220.4  3317612
# 5021  2025-01-27T11:00:00+05:30  1220.50  1233.50  1220.00  1230.8  3039450
# 5022  2025-01-27T13:00:00+05:30  1230.80  1235.90  1225.00  1230.0  2343373
# 5023  2025-01-27T15:00:00+05:30  1230.15  1231.65  1227.85  1229.0   789840
#
#       Support  Resistance        RSI  MACD_Histogram        ATR     Upper_BB  \
# 5019  1227.25      1326.0  33.954053       -4.929693  10.807905  1312.723006
# 5020  1227.25      1326.0  24.301942       -6.311105  11.914483  1312.209682
# 5021  1227.25      1326.0  32.588649       -6.166885  12.027734  1309.614363
# 5022  1227.25      1326.0  32.295773       -5.774692  11.947182  1305.061486
# 5023  1227.25      1326.0  31.909730       -5.247235  11.365240  1299.697868
#
#          Lower_BB  Middle_BB     100_MA     50_MA      20_MA  \
# 5019  1239.111994  1275.9175  1245.8535  1264.042  1275.9175
# 5020  1230.685318  1271.4475  1245.7135  1263.120  1271.4475
# 5021  1226.085637  1267.8500  1245.8070  1262.426  1267.8500
# 5022  1223.038514  1264.0500  1245.9870  1261.975  1264.0500
# 5023  1220.902132  1260.3000  1246.2240  1261.473  1260.3000
#
#       Rolling_Volume_Mean
# 5019            2735702.2
# 5020            2833142.0
# 5021            2922906.3
# 5022            2991081.7
# 5023            2789937.4

# %%
# Price Action Logic
def detect_price_action(row):
    body = abs(row['Close'] - row['Open'])
    wick_up = row['High'] - max(row['Close'], row['Open'])
    wick_down = min(row['Close'], row['Open']) - row['Low']

    if wick_up > 2 * body and wick_down < body and row['Close'] < row['Open']:
        return 'Shooting Star'
    elif wick_down > 2 * body and wick_up < body and row['Close'] > row['Open']:
        return 'Hammer'
    elif body > wick_up + wick_down and row['Volume'] > row['Rolling_Volume_Mean']:
        if row['Close'] < row['Open']:
            return 'Large Body Down'
        elif row['Close'] > row['Open']:
            return 'Large Body Up'
    return None

data['Price_Action'] = data.apply(detect_price_action, axis=1)
data.tail()
# Out:
#                            Date     Open     High      Low   Close   Volume  \
# 5019  2025-01-24T15:00:00+05:30  1246.10  1248.00  1243.50  1246.3  1776011
# 5020  2025-01-27T09:00:00+05:30  1239.10  1240.45  1220.00  1220.4  3317612
# 5021  2025-01-27T11:00:00+05:30  1220.50  1233.50  1220.00  1230.8  3039450
# 5022  2025-01-27T13:00:00+05:30  1230.80  1235.90  1225.00  1230.0  2343373
# 5023  2025-01-27T15:00:00+05:30  1230.15  1231.65  1227.85  1229.0   789840
#
#       Support  Resistance        RSI  MACD_Histogram        ATR     Upper_BB  \
# 5019  1227.25      1326.0  33.954053       -4.929693  10.807905  1312.723006
# 5020  1227.25      1326.0  24.301942       -6.311105  11.914483  1312.209682
# 5021  1227.25      1326.0  32.588649       -6.166885  12.027734  1309.614363
# 5022  1227.25      1326.0  32.295773       -5.774692  11.947182  1305.061486
# 5023  1227.25      1326.0  31.909730       -5.247235  11.365240  1299.697868
#
#          Lower_BB  Middle_BB     100_MA     50_MA      20_MA  \
# 5019  1239.111994  1275.9175  1245.8535  1264.042  1275.9175
# 5020  1230.685318  1271.4475  1245.7135  1263.120  1271.4475
# 5021  1226.085637  1267.8500  1245.8070  1262.426  1267.8500
# 5022  1223.038514  1264.0500  1245.9870  1261.975  1264.0500
# 5023  1220.902132  1260.3000  1246.2240  1261.473  1260.3000
#
#       Rolling_Volume_Mean     Price_Action
# 5019            2735702.2             None
# 5020            2833142.0  Large Body Down
# 5021            2922906.3    Large Body Up
# 5022            2991081.7             None
# 5023            2789937.4             None

# %%
# Backtesting Logic
position = 0
entry_price = None
stop_loss_price = None
above_ma_volume_counter = 0
exit_candle = 0
data['Buy_Date'] = None
data['Sell_Date'] = None
data['Stop_Loss'] = None

# %%
# def find_entry(data, start_index, position=0):
#     for index in range(start_index, len(data)):

#         row = data.iloc[index]
#         prevRow = data.iloc[index - 1]

#         # Long Condition 1
#         if (
#             position == 0
#             and row['RSI'] <= 40
#             and row['MACD_Histogram'] > prevRow['MACD_Histogram']
#             # and prevRow['Open'] < prevRow['Lower_BB'] and prevRow['Close'] > prevRow['Lower_BB']
#             and prevRow['Close'] > row['20_MA']
#         ):
#             entry_price = row['Open']
#             entry_date = row['Date']
#             stop_loss_price = min(entry_price - 2 * row['ATR'], row['Support'])
#             return index, entry_date, entry_price, stop_loss_price, 1


#         if (
#             position == 0
#             and row['RSI'] <= 50
#             and row['MACD_Histogram'] > prevRow['MACD_Histogram']
#             and prevRow['Open'] < prevRow['Lower_BB'] and prevRow['Close'] > prevRow['Lower_BB']
#             and row['Open'] > row['Support']
#         ):
#             entry_price = row['Open']
#             entry_date = row['Date']
#             stop_loss_price = min(entry_price - 2 * row['ATR'], row['Support'])
#             return index, entry_date, entry_price, stop_loss_price, 1

#         # Long Condition 2 (Hammer Reversal)
#         if (
#             position == 0
#             and prevRow['Price_Action'] == 'Hammer'
#             and row['Volume'] > row['Rolling_Volume_Mean']
#             and row['RSI'] <= 50
#             and row['Close'] > 1.01 * row['Lower_BB']

#         ):
#             entry_price = row['Close']
#             entry_date = row['Date']
#             stop_loss_price = min(entry_price - 2 * row['ATR'], row['Support'])
#             return index, entry_date, entry_price, stop_loss_price, 1

#         # Large Body Up
#         if (
#             position == 0
#             and prevRow['Price_Action'] == 'Large Candle Up'
#             # and row['Open'] < row['Close']
#             and row['Volume'] > row['Rolling_Volume_Mean']
#             and row['RSI'] <= 50
#             and row['Close'] > 1.01 * row['Lower_BB']
#         ):
#             entry_price = row['Open']
#             entry_date = row['Date']
#             stop_loss_price = min(entry_price - 2 * row['ATR'], row['Support'])
#             return index, entry_date, entry_price, stop_loss_price, 1

#         # Short Condition 1 (existing)
#         if (
#             position == 0
#             and row['RSI'] >= 60
#             and row['MACD_Histogram'] < prevRow['MACD_Histogram']
#             # and prevRow['Close'] < prevRow['Upper_BB']
#             and prevRow['Close'] < row['20_MA']
#             # and row['Open'] < row['Resistance']
#         ):
#             entry_price = row['Open']
#             entry_date = row['Date']
#             stop_loss_price = max(entry_price + 2 * row['ATR'], row['Resistance'])
#             return index, entry_date, entry_price, stop_loss_price, -1

#         if (
#             position == 0
#             and row['RSI'] >= 60
#             and row['MACD_Histogram'] < prevRow['MACD_Histogram']
#             and prevRow['Close'] < prevRow['Upper_BB']
#             # and row['Open'] < row['20_MA']
#             and row['Open'] < row['Resistance']
#         ):
#             entry_price = row['Open']
#             entry_date = row['Date']
#             stop_loss_price = max(entry_price + 2 * row['ATR'], row['Resistance'])
#             return index, entry_date, entry_price, stop_loss_price, -1

#         # Short Condition 2 (Shooting Star Reversal)
#         if (
#             position == 0
#             and prevRow['Price_Action'] == 'Shooting Star'
#             # and row['Close'] < row['Open']
#             and row['Volume'] > row['Rolling_Volume_Mean']
#             and row['RSI'] >= 50
#             and row['Open'] <= 0.99 * row['Upper_BB']
#         ):
#             entry_price = row['Close']
#             entry_date = row['Date']
#             stop_loss_price = max(entry_price + 2 * row['ATR'], row['Resistance'])
#             return index, entry_date, entry_price, stop_loss_price, -1

#         # Large Body Down
#         if (
#             position == 0
#             and prevRow['Price_Action'] == 'Large Candle Down'
#             # and row['Open'] > row['Close']
#             and row['Volume'] > row['Rolling_Volume_Mean']
#             and row['RSI'] >= 50
#             and row['Open'] <= 0.99 * row['Upper_BB']
#         ):
#             entry_price = row['Open']
#             entry_date = row['Date']
#             stop_loss_price = max(entry_price + 2 * row['ATR'], row['Resistance'])
#             return index, entry_date, entry_price, stop_loss_price, -1

#     # If no entry signal found
#     return None, None, None, None, 0

# %%
def find_entry(data, start_index, position=0):
    for index in range(start_index, len(data)):
        row = data.iloc[index]
        prevRow = data.iloc[index - 1]


        # Long Conditions
        # Long Condition 1: RSI, MACD, Moving Average, Volume, and Trend Filter
        if (
            position == 0
            and row['RSI'] >= 50
            and row['MACD_Histogram'] > prevRow['MACD_Histogram']
            and row['High'] > prevRow['High']
            and row['Close'] > prevRow['Support']
            and row['Close'] > row['20_MA']
            and row['Volume'] > prevRow['Volume']
            and row['Close'] < row['100_MA']
        ):
            entry_price = row['Open']
            entry_date = row['Date']
            stop_loss_price = min(entry_price - 1.5 * row['ATR'], row['Support'])
            return index, entry_date, entry_price, stop_loss_price, 1, 1

        # Long Condition 2: Hammer Reversal
        if (
            position == 0
            and prevRow['Price_Action'] == 'Hammer'
            and prevRow['Volume'] > prevRow['Rolling_Volume_Mean']
            and row['Close'] < prevRow['Close']
            and row['MACD_Histogram'] > prevRow['MACD_Histogram']
            and row['RSI'] <= 40
        ):
            entry_price = row['Close']
            entry_date = row['Date']
            stop_loss_price = min(entry_price - 1.5 * row['ATR'], row['Support'])
            return index, entry_date, entry_price, stop_loss_price, 1, 2

        # Long Condition 3: Large Candle Up
        if (
            position == 0
            and prevRow['Price_Action'] == 'Large Body Up'
            and row['Close'] > prevRow['Close']
            and row['MACD_Histogram'] > prevRow['MACD_Histogram']
            and row['RSI'] <= 40
        ):
            entry_price = row['Close']
            entry_date = row['Date']
            stop_loss_price = min(entry_price - 1.5 * row['ATR'], row['Support'])
            return index, entry_date, entry_price, stop_loss_price, 1, 3

        # Short Conditions
        # Short Condition 1: RSI, MACD, Moving Average, Volume, and Trend Filter
        if (
            position == 0
            and row['RSI'] <= 50
            and row['MACD_Histogram'] < prevRow['MACD_Histogram']
            and row['Low'] < prevRow['Low']
            and row['Close'] < prevRow['Resistance']
            and row['Close'] < row['20_MA']
            and row['Volume'] > prevRow['Volume']
            and row['Close'] > row['100_MA']
        ):
            entry_price = row['Open']
            entry_date = row['Date']
            stop_loss_price = max(entry_price + 1.5 * row['ATR'], row['Resistance'])
            return index, entry_date, entry_price, stop_loss_price, -1, 4

        # Short Condition 2: Shooting Star Reversal
        if (
            position == 0
            and prevRow['Price_Action'] == 'Shooting Star'
            and prevRow['Volume'] > prevRow['Rolling_Volume_Mean']
            and row['MACD_Histogram'] < prevRow['MACD_Histogram']
            and row['RSI'] >= 60
            and row['Close'] < prevRow['Close']
        ):
            entry_price = row['Close']
            entry_date = row['Date']
            stop_loss_price = max(entry_price + 1.5 * row['ATR'], row['Resistance'])
            return index, entry_date, entry_price, stop_loss_price, -1, 5

        # Short Condition 3: Large Candle Down
        if (
            position == 0
            and prevRow['Price_Action'] == 'Large Body Down'
            and row['MACD_Histogram'] < prevRow['MACD_Histogram']
            and row['RSI'] >= 60
            and row['Close'] < prevRow['Close']
        ):
            entry_price = row['Open']
            entry_date = row['Date']
            stop_loss_price = max(entry_price + 1.5 * row['ATR'], row['Resistance'])
            return index, entry_date, entry_price, stop_loss_price, -1, 6

    # If no entry signal found
    return None, None, None, None, 0, 0

# %%
def find_exit(data, entry_index, entry_price, stop_loss_price, position):
    support = float('nan')
    resistance = float('nan')
    above_ma_volume_counter = 0
    exit_candle = 0

    for index in range(entry_index + 1, len(data)):
        row = data.iloc[index]
        prevRow = data.iloc[index - 1] if index > 0 else None

        # Update support and resistance levels
        if prevRow is not None:
            if pd.notna(prevRow['Support']):
                support = prevRow['Support']
            if pd.notna(prevRow['Resistance']):
                resistance = prevRow['Resistance']

        # Exit logic for Buy position
        if position == 1:
            # Stop loss hit
            if row['Close'] <= stop_loss_price:
                return index, row['Date'], row['Close']

            # Case 1: Rejection at resistance or 100 MA
            # elif (row['High'] >= prevRow['Resistance'] and row['Close'] < prevRow['Resistance']) or \
            #      (row['High'] >= row['100_MA'] and row['Close'] <= row['100_MA']):
            #     return index, row['Date'], row['Close']


            elif (row['High'] >= prevRow['Resistance'] or row['High'] >= row['100_MA']):
              return index, row['Date'], row['Close']

            # Case 2: High volume red candles
            # elif (row['Open'] > row['100_MA'] or row['Open'] > resistance) and \
            #      (row['Close'] < row['100_MA'] or row['Close'] < resistance):
            #     if row['Volume'] > row['Rolling_Volume_Mean']:
            #         above_ma_volume_counter += 1
            #     elif row['Volume'] <= row['Rolling_Volume_Mean']:
            #         exit_candle += 1
            #     else:
            #       above_ma_volume_counter = 0
            #       exit_candle = 0

            # # # Exit after consecutive high volume candles
            # elif above_ma_volume_counter >= 1 and (row['Open'] < row['100_MA'] or row['Open'] < resistance):
            #     return index, row['Date'], row['Open']

            # # # Case 3: Low volume green candles
            # elif (row['Open'] < row['100_MA'] or row['Open'] < resistance) and exit_candle >= 1:
            #     return index, row['Date'], row['Close']



        # Exit logic for Sell position
        if position == -1:
            # Stop loss hit
            if row['Close'] >= stop_loss_price:
                return index, row['Date'], row['Close']

            # Case 1: Rejection at support or 100 MA
            # elif (row['Low'] <= support and row['Close'] > support) or \
            #      (row['Low'] < row['100_MA'] and row['Close'] > row['100_MA']):
            #     return index, row['Date'], row['Close']

            elif (row['Low'] <= prevRow['Support'] or row['Low'] <= row['100_MA']):
              return index, row['Date'], row['Close']

            # #Case 2: High volume green candles
            # elif (row['Open'] < row['100_MA'] or row['Open'] < support) and \
            #      (row['Close'] > row['100_MA'] or row['Close'] > support):
            #     if row['Volume'] > row['Rolling_Volume_Mean']:
            #         above_ma_volume_counter += 1
            #     elif row['Volume'] <= row['Rolling_Volume_Mean']:
            #         exit_candle += 1

            # # # Exit after consecutive high volume candles
            # elif above_ma_volume_counter >= 1 and (row['Open'] > row['100_MA'] or row['Open'] > support):
            #     return index, row['Date'], row['Open']

            # # # Case 3: Low volume green candles
            # elif (row['Open'] > row['100_MA'] or row['Open'] > support) and exit_candle >= 1:
            #     return index, row['Date'], row['Close']

    # If no exit is found within the dataset
    return None, None, None

# %%
# Main loop to calculate PnL and track trades
def calculate_pnl(data):
    position = 0
    start_index = 10
    total_pnl = 0
    num_trades = 0
    profit_trades = 0

    while start_index < len(data):
        # Find entry
        entry_index, entry_date, entry_price, stop_loss_price, position, entry_cond = find_entry(data, start_index, position)
        if entry_index is None:  # No more entries
            break

        print(f"Entry: {entry_date}, Price: {entry_price}, Entry_type: {position}, Entry_Cond: {entry_cond}")

        # Find exit
        exit_index, exit_date, exit_price = find_exit(data, entry_index, entry_price, stop_loss_price, position)
        if exit_index is None:  # No exit found
            break

        # Calculate PnL for the trade
        if position == 1:  # Long Position
           pnl = exit_price - entry_price
        elif position == -1:  # Short Position
           pnl = entry_price - exit_price

        if(pnl > 0):
            profit_trades+=1
        total_pnl += pnl
        num_trades += 1

        print(f"Exit: {exit_date}, Price: {exit_price}, PnL: {pnl}")

        start_index = exit_index + 1
        position = 0

    print(f"Total PnL: {total_pnl}, Number of Trades: {num_trades}, Successful Trades: {profit_trades}")
    return total_pnl, num_trades

# Run the calculation
calculate_pnl(data)
# Out:
# Entry: 2020-02-05T09:00:00+05:30, Price: 645.203225, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-02-12T09:00:00+05:30, Price: 657.8383985, PnL: 12.635173500000064
# Entry: 2020-02-12T15:00:00+05:30, Price: 658.985007, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-02-13T09:00:00+05:30, Price: 658.737699, PnL: -0.24730799999997544
# Entry: 2020-03-11T11:00:00+05:30, Price: 520.132992, Entry_type: 1, Entry_Cond: 3
# Exit: 2020-03-12T09:00:00+05:30, Price: 482.0700935, PnL: -38.06289849999996
# Entry: 2020-03-13T13:00:00+05:30, Price: 494.480442, Entry_type: 1, Entry_Cond: 3
# Exit: 2020-03-19T09:00:00+05:30, Price: 405.382234, PnL: -89.098208
# Entry: 2020-03-25T09:00:00+05:30, Price: 433.3729655, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-03-25T11:00:00+05:30, Price: 463.229746, PnL: 29.856780499999957
# Entry: 2020-03-25T13:00:00+05:30, Price: 463.229746, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-04-03T09:00:00+05:30, Price: 476.3820175, PnL: 13.15227150000004
# Entry: 2020-04-03T13:00:00+05:30, Price: 478.427926, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-04-07T09:00:00+05:30, Price: 511.702049, PnL: 33.274122999999975
# Entry: 2020-04-08T13:00:00+05:30, Price: 535.5559975, Entry_type: -1, Entry_Cond: 6
# Exit: 2020-04-15T13:00:00+05:30, Price: 519.6608595, PnL: 15.895137999999974
# Entry: 2020-04-24T15:00:00+05:30, Price: 639.874869, Entry_type: -1, Entry_Cond: 6
# Exit: 2020-05-04T09:00:00+05:30, Price: 651.3859165, PnL: -11.511047500000018
# Entry: 2020-05-12T15:00:00+05:30, Price: 676.656264, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-05-14T13:00:00+05:30, Price: 654.566339, PnL: 22.089924999999994
# Entry: 2020-05-15T09:00:00+05:30, Price: 655.474198, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-05-15T11:00:00+05:30, Price: 645.9416785, PnL: 9.532519500000035
# Entry: 2020-05-19T13:00:00+05:30, Price: 655.860038, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-05-19T15:00:00+05:30, Price: 639.5412725, PnL: 16.31876550000004
# Entry: 2020-05-22T09:00:00+05:30, Price: 659.014848, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-05-26T11:00:00+05:30, Price: 648.778738, PnL: 10.236110000000053
# Entry: 2020-06-08T11:00:00+05:30, Price: 720.499599, Entry_type: -1, Entry_Cond: 6
# Exit: 2020-06-11T13:00:00+05:30, Price: 697.8258205, PnL: 22.673778500000026
# Entry: 2020-06-12T09:00:00+05:30, Price: 680.89425, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-06-12T13:00:00+05:30, Price: 717.6625395, PnL: -36.76828949999992
# Entry: 2020-06-16T11:00:00+05:30, Price: 737.5900445, Entry_type: -1, Entry_Cond: 6
# Exit: 2020-06-19T09:00:00+05:30, Price: 761.7163975, PnL: -24.126352999999995
# Entry: 2020-06-30T13:00:00+05:30, Price: 782.8922085, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-07-02T11:00:00+05:30, Price: 800.595459, PnL: -17.703250499999967
# Entry: 2020-07-07T11:00:00+05:30, Price: 834.1181525, Entry_type: -1, Entry_Cond: 6
# Exit: 2020-07-10T13:00:00+05:30, Price: 851.3447775, PnL: -17.226625000000013
# Entry: 2020-07-31T09:00:00+05:30, Price: 959.8339275, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-07-31T11:00:00+05:30, Price: 939.1347425, PnL: 20.699184999999943
# Entry: 2020-08-03T09:00:00+05:30, Price: 931.1455835, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-08-03T11:00:00+05:30, Price: 921.726546, PnL: 9.419037500000059
# Entry: 2020-08-11T09:00:00+05:30, Price: 969.0486965, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-08-11T11:00:00+05:30, Price: 964.146258, PnL: 4.902438500000017
# Entry: 2020-08-14T13:00:00+05:30, Price: 971.545309, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-08-14T15:00:00+05:30, Price: 959.516177, PnL: 12.029132000000004
# Entry: 2020-08-17T09:00:00+05:30, Price: 955.5215975, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-08-20T15:00:00+05:30, Price: 951.912858, PnL: 3.608739499999956
# Entry: 2020-09-08T13:00:00+05:30, Price: 958.699104, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-09-09T09:00:00+05:30, Price: 964.2143475, PnL: 5.515243499999997
# Entry: 2020-09-21T13:00:00+05:30, Price: 1046.262105, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-09-21T15:00:00+05:30, Price: 1023.996863, PnL: 22.265242000000057
# Entry: 2020-09-22T09:00:00+05:30, Price: 1033.597472, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-09-24T09:00:00+05:30, Price: 1000.64219, PnL: 32.9552819999999
# Entry: 2020-09-24T13:00:00+05:30, Price: 1004.704859, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-09-24T15:00:00+05:30, Price: 990.1110255, PnL: 14.593833500000073
# Entry: 2020-10-01T13:00:00+05:30, Price: 1018.617798, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-10-05T11:00:00+05:30, Price: 1004.069358, PnL: 14.548440000000028
# Entry: 2020-10-09T09:00:00+05:30, Price: 1014.532433, Entry_type: -1, Entry_Cond: 4
# Exit: 2020-10-09T11:00:00+05:30, Price: 1013.397609, PnL: 1.1348239999999805
# Entry: 2020-10-29T11:00:00+05:30, Price: 920.569026, Entry_type: 1, Entry_Cond: 3
# Exit: 2020-11-02T09:00:00+05:30, Price: 885.9115085, PnL: -34.65751750000004
# Entry: 2020-11-04T13:00:00+05:30, Price: 869.2749925, Entry_type: 1, Entry_Cond: 3
# Exit: 2020-11-09T09:00:00+05:30, Price: 930.850529, PnL: 61.5755365
# Entry: 2020-11-10T09:00:00+05:30, Price: 942.8115715, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-11-10T11:00:00+05:30, Price: 942.17607, PnL: -0.6355015000000321
# Entry: 2020-11-25T09:00:00+05:30, Price: 898.78041, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-12-03T09:00:00+05:30, Price: 893.9233645, PnL: -4.857045499999913
# Entry: 2020-12-07T09:00:00+05:30, Price: 880.8955877, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-12-08T09:00:00+05:30, Price: 908.7214661, PnL: 27.82587840000008
# Entry: 2020-12-24T09:00:00+05:30, Price: 883.8007365, Entry_type: 1, Entry_Cond: 1
# Exit: 2020-12-24T11:00:00+05:30, Price: 898.0995158, PnL: 14.298779299999978
# Entry: 2021-01-04T09:00:00+05:30, Price: 905.6347455, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-01-04T11:00:00+05:30, Price: 897.2143532, PnL: 8.420392300000003
# Entry: 2021-01-12T13:00:00+05:30, Price: 876.2428103, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-01-12T15:00:00+05:30, Price: 888.362728, PnL: 12.119917699999974
# Entry: 2021-01-13T09:00:00+05:30, Price: 891.3132697, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-01-15T09:00:00+05:30, Price: 892.85663, PnL: 1.5433603000000176
# Entry: 2021-02-03T09:00:00+05:30, Price: 875.312255, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-02-08T09:00:00+05:30, Price: 885.117132, PnL: 9.80487699999992
# Entry: 2021-02-22T09:00:00+05:30, Price: 944.17336, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-02-22T15:00:00+05:30, Price: 911.535829, PnL: 32.63753099999997
# Entry: 2021-03-12T13:00:00+05:30, Price: 982.5757955, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-03-12T15:00:00+05:30, Price: 970.319699, PnL: 12.256096500000012
# Entry: 2021-03-15T09:00:00+05:30, Price: 971.4318265, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-03-15T11:00:00+05:30, Price: 947.668617, PnL: 23.763209500000016
# Entry: 2021-03-15T15:00:00+05:30, Price: 957.2919225, Entry_type: 1, Entry_Cond: 3
# Exit: 2021-03-16T09:00:00+05:30, Price: 959.0168545, PnL: 1.724931999999967
# Entry: 2021-03-19T15:00:00+05:30, Price: 937.387114, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-03-23T09:00:00+05:30, Price: 952.389484, PnL: 15.002370000000042
# Entry: 2021-03-30T13:00:00+05:30, Price: 921.2499205, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-04-12T09:00:00+05:30, Price: 874.4724855, PnL: -46.77743500000008
# Entry: 2021-04-26T09:00:00+05:30, Price: 871.54464, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-04-26T11:00:00+05:30, Price: 883.301414, PnL: 11.756774000000064
# Entry: 2021-04-26T13:00:00+05:30, Price: 883.301414, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-04-26T15:00:00+05:30, Price: 879.6472815, PnL: -3.6541325000000597
# Entry: 2021-04-27T09:00:00+05:30, Price: 880.62323, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-04-27T11:00:00+05:30, Price: 898.5761415, PnL: 17.952911499999914
# Entry: 2021-05-25T09:00:00+05:30, Price: 906.224854, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-05-25T11:00:00+05:30, Price: 896.5561555, PnL: 9.668698500000005
# Entry: 2021-05-25T13:00:00+05:30, Price: 896.578852, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-05-25T15:00:00+05:30, Price: 891.131698, PnL: 5.447153999999955
# Entry: 2021-06-09T13:00:00+05:30, Price: 1001.8678, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-06-14T13:00:00+05:30, Price: 1020.887446, PnL: -19.019645999999966
# Entry: 2021-06-16T15:00:00+05:30, Price: 1006.724845, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-06-24T09:00:00+05:30, Price: 989.2485595, PnL: 17.476285499999904
# Entry: 2021-06-24T11:00:00+05:30, Price: 989.271256, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-06-24T13:00:00+05:30, Price: 985.889481, PnL: 3.381774999999948
# Entry: 2021-07-05T09:00:00+05:30, Price: 969.7976805, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-07-05T11:00:00+05:30, Price: 974.5866365, PnL: 4.788956000000098
# Entry: 2021-07-05T13:00:00+05:30, Price: 974.5412435, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-07-05T15:00:00+05:30, Price: 976.039211, PnL: 1.4979675000000725
# Entry: 2021-07-16T09:00:00+05:30, Price: 947.6913135, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-07-16T11:00:00+05:30, Price: 955.4762045, PnL: 7.784891000000016
# Entry: 2021-07-16T13:00:00+05:30, Price: 955.498901, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-07-16T15:00:00+05:30, Price: 958.880676, PnL: 3.381774999999948
# Entry: 2021-07-22T09:00:00+05:30, Price: 961.8766105, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-07-23T09:00:00+05:30, Price: 962.6936835, PnL: 0.8170730000000503
# Entry: 2021-08-02T09:00:00+05:30, Price: 932.507372, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-08-02T13:00:00+05:30, Price: 941.1320325, PnL: 8.624660500000005
# Entry: 2021-08-03T13:00:00+05:30, Price: 942.5165175, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-08-03T15:00:00+05:30, Price: 947.6913135, PnL: 5.174796000000015
# Entry: 2021-08-23T09:00:00+05:30, Price: 986.842733, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-08-25T09:00:00+05:30, Price: 1002.276336, PnL: -15.433603000000062
# Entry: 2021-09-13T09:00:00+05:30, Price: 1104.410474, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-09-13T11:00:00+05:30, Price: 1080.238728, PnL: 24.171745999999985
# Entry: 2021-09-13T13:00:00+05:30, Price: 1080.216031, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-09-13T15:00:00+05:30, Price: 1076.516506, PnL: 3.699524999999994
# Entry: 2021-09-17T15:00:00+05:30, Price: 1098.600176, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-09-23T09:00:00+05:30, Price: 1118.459592, PnL: -19.85941600000001
# Entry: 2021-10-06T11:00:00+05:30, Price: 1177.016497, Entry_type: -1, Entry_Cond: 6
# Exit: 2021-10-08T11:00:00+05:30, Price: 1197.488718, PnL: -20.47222099999999
# Entry: 2021-10-11T15:00:00+05:30, Price: 1207.316291, Entry_type: -1, Entry_Cond: 6
# Exit: 2021-10-12T11:00:00+05:30, Price: 1207.543256, PnL: -0.22696499999983644
# Entry: 2021-10-18T15:00:00+05:30, Price: 1229.059514, Entry_type: -1, Entry_Cond: 5
# Exit: 2021-10-21T09:00:00+05:30, Price: 1203.821034, PnL: 25.23847999999998
# Entry: 2021-10-21T13:00:00+05:30, Price: 1193.199084, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-10-25T09:00:00+05:30, Price: 1180.443665, PnL: 12.755419000000074
# Entry: 2021-10-28T09:00:00+05:30, Price: 1189.29529, Entry_type: -1, Entry_Cond: 4
# Exit: 2021-10-28T11:00:00+05:30, Price: 1181.873543, PnL: 7.421747000000096
# Entry: 2021-11-01T13:00:00+05:30, Price: 1153.230591, Entry_type: 1, Entry_Cond: 3
# Exit: 2021-11-03T11:00:00+05:30, Price: 1128.287165, PnL: -24.943426000000045
# Entry: 2021-11-10T13:00:00+05:30, Price: 1153.43486, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-11-10T15:00:00+05:30, Price: 1157.474832, PnL: 4.039972000000034
# Entry: 2021-11-12T11:00:00+05:30, Price: 1164.079507, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-11-12T13:00:00+05:30, Price: 1177.12998, PnL: 13.05047300000001
# Entry: 2021-11-25T09:00:00+05:30, Price: 1077.174704, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-11-25T13:00:00+05:30, Price: 1131.2831, PnL: 54.108396000000084
# Entry: 2021-11-29T09:00:00+05:30, Price: 1107.179444, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-12-03T09:00:00+05:30, Price: 1115.985676, PnL: 8.806231999999909
# Entry: 2021-12-09T09:00:00+05:30, Price: 1105.318333, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-12-09T11:00:00+05:30, Price: 1121.228562, PnL: 15.910229000000072
# Entry: 2021-12-22T13:00:00+05:30, Price: 1063.556819, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-12-24T13:00:00+05:30, Price: 1078.990422, PnL: 15.433603000000176
# Entry: 2021-12-28T13:00:00+05:30, Price: 1083.075787, Entry_type: 1, Entry_Cond: 1
# Exit: 2021-12-28T15:00:00+05:30, Price: 1088.704513, PnL: 5.628725999999915
# Entry: 2022-01-20T09:00:00+05:30, Price: 1134.846447, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-01-24T11:00:00+05:30, Price: 1094.333239, PnL: 40.51320799999985
# Entry: 2022-02-01T09:00:00+05:30, Price: 1093.062236, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-02-08T15:00:00+05:30, Price: 1069.480599, PnL: -23.581637
# Entry: 2022-02-09T09:00:00+05:30, Price: 1076.334934, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-02-09T11:00:00+05:30, Price: 1075.358986, PnL: -0.9759480000000167
# Entry: 2022-02-09T13:00:00+05:30, Price: 1075.472468, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-02-09T15:00:00+05:30, Price: 1081.940963, PnL: 6.468495000000075
# Entry: 2022-02-15T13:00:00+05:30, Price: 1079.739405, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-02-15T15:00:00+05:30, Price: 1097.578835, PnL: 17.839429999999993
# Entry: 2022-02-16T09:00:00+05:30, Price: 1103.048685, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-02-16T11:00:00+05:30, Price: 1098.214336, PnL: -4.834348999999975
# Entry: 2022-02-28T13:00:00+05:30, Price: 1055.862714, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-03-02T09:00:00+05:30, Price: 1072.11339, PnL: 16.250675999999885
# Entry: 2022-03-08T15:00:00+05:30, Price: 1014.759398, Entry_type: 1, Entry_Cond: 3
# Exit: 2022-03-09T13:00:00+05:30, Price: 1070.547333, PnL: 55.78793499999995
# Entry: 2022-04-06T09:00:00+05:30, Price: 1174.36101, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-04-06T11:00:00+05:30, Price: 1188.682485, PnL: -14.321474999999964
# Entry: 2022-04-07T09:00:00+05:30, Price: 1177.992446, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-04-07T11:00:00+05:30, Price: 1177.470427, PnL: 0.5220190000000002
# Entry: 2022-04-11T09:00:00+05:30, Price: 1180.2167, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-04-12T09:00:00+05:30, Price: 1167.506674, PnL: 12.71002599999997
# Entry: 2022-04-12T13:00:00+05:30, Price: 1167.27971, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-04-12T15:00:00+05:30, Price: 1162.536146, PnL: 4.743564000000106
# Entry: 2022-05-04T09:00:00+05:30, Price: 1264.193658, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-05-05T09:00:00+05:30, Price: 1230.421303, PnL: 33.772354999999834
# Entry: 2022-05-17T09:00:00+05:30, Price: 1105.363726, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-05-20T13:00:00+05:30, Price: 1173.634722, PnL: 68.27099599999997
# Entry: 2022-05-31T13:00:00+05:30, Price: 1206.226861, Entry_type: -1, Entry_Cond: 6
# Exit: 2022-06-02T11:00:00+05:30, Price: 1234.211614, PnL: -27.984752999999955
# Entry: 2022-06-06T11:00:00+05:30, Price: 1254.297995, Entry_type: -1, Entry_Cond: 5
# Exit: 2022-06-08T09:00:00+05:30, Price: 1243.948402, PnL: 10.349592999999913
# Entry: 2022-06-08T13:00:00+05:30, Price: 1242.632007, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-06-08T15:00:00+05:30, Price: 1236.526655, PnL: 6.105352000000039
# Entry: 2022-06-10T11:00:00+05:30, Price: 1260.108292, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-06-10T13:00:00+05:30, Price: 1231.760395, PnL: 28.347896999999875
# Entry: 2022-06-13T09:00:00+05:30, Price: 1202.913175, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-06-14T11:00:00+05:30, Price: 1187.888109, PnL: 15.025065999999924
# Entry: 2022-06-29T09:00:00+05:30, Price: 1138.092043, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-06-29T11:00:00+05:30, Price: 1166.417243, PnL: 28.325199999999995
# Entry: 2022-06-29T13:00:00+05:30, Price: 1166.144886, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-06-29T15:00:00+05:30, Price: 1171.2062, PnL: 5.0613140000000385
# Entry: 2022-06-30T09:00:00+05:30, Price: 1171.13811, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-07-01T09:00:00+05:30, Price: 1115.758711, PnL: -55.37939900000015
# Entry: 2022-07-12T09:00:00+05:30, Price: 1091.246518, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-07-19T09:00:00+05:30, Price: 1101.891165, PnL: 10.644647000000077
# Entry: 2022-08-19T11:00:00+05:30, Price: 1204.025303, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-08-19T13:00:00+05:30, Price: 1188.637092, PnL: 15.388210999999956
# Entry: 2022-08-22T09:00:00+05:30, Price: 1187.933502, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-08-22T11:00:00+05:30, Price: 1177.856267, PnL: 10.0772350000002
# Entry: 2022-08-26T09:00:00+05:30, Price: 1195.196374, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-08-29T09:00:00+05:30, Price: 1188.569003, PnL: 6.627371000000039
# Entry: 2022-08-29T13:00:00+05:30, Price: 1188.024288, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-08-29T15:00:00+05:30, Price: 1179.149966, PnL: 8.87432200000012
# Entry: 2022-09-01T09:00:00+05:30, Price: 1172.341023, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-09-01T11:00:00+05:30, Price: 1170.321037, PnL: 2.019986000000017
# Entry: 2022-09-06T13:00:00+05:30, Price: 1178.015142, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-09-06T15:00:00+05:30, Price: 1178.786822, PnL: 0.7716800000000603
# Entry: 2022-09-12T09:00:00+05:30, Price: 1166.848476, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-09-12T11:00:00+05:30, Price: 1180.443665, PnL: 13.595189000000119
# Entry: 2022-09-12T13:00:00+05:30, Price: 1180.647933, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-09-12T15:00:00+05:30, Price: 1179.331538, PnL: -1.3163950000000568
# Entry: 2022-10-04T09:00:00+05:30, Price: 1088.432155, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-10-04T13:00:00+05:30, Price: 1095.672331, PnL: 7.2401760000000195
# Entry: 2022-10-06T09:00:00+05:30, Price: 1102.594756, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-10-06T11:00:00+05:30, Price: 1105.976531, PnL: 3.3817750000000615
# Entry: 2022-10-14T09:00:00+05:30, Price: 1096.239743, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-10-18T09:00:00+05:30, Price: 1113.216706, PnL: 16.97696299999984
# Entry: 2022-10-25T13:00:00+05:30, Price: 1114.442316, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-10-31T09:00:00+05:30, Price: 1154.796648, PnL: -40.35433200000011
# Entry: 2022-11-16T13:00:00+05:30, Price: 1184.619816, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-11-16T15:00:00+05:30, Price: 1176.74414, PnL: 7.875675999999885
# Entry: 2022-11-17T09:00:00+05:30, Price: 1173.385061, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-11-18T11:00:00+05:30, Price: 1173.816294, PnL: -0.4312330000000202
# Entry: 2022-11-21T09:00:00+05:30, Price: 1174.769546, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-11-21T11:00:00+05:30, Price: 1159.063586, PnL: 15.705960000000005
# Entry: 2022-11-21T13:00:00+05:30, Price: 1159.040889, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-11-21T15:00:00+05:30, Price: 1157.928762, PnL: 1.1121270000001005
# Entry: 2022-12-05T13:00:00+05:30, Price: 1224.293255, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-12-07T11:00:00+05:30, Price: 1210.516494, PnL: 13.776761000000079
# Entry: 2022-12-07T15:00:00+05:30, Price: 1211.991765, Entry_type: -1, Entry_Cond: 4
# Exit: 2022-12-08T09:00:00+05:30, Price: 1204.660804, PnL: 7.330960999999888
# Entry: 2022-12-20T13:00:00+05:30, Price: 1172.908435, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-12-20T15:00:00+05:30, Price: 1190.112363, PnL: 17.203927999999905
# Entry: 2022-12-21T09:00:00+05:30, Price: 1189.74922, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-12-23T11:00:00+05:30, Price: 1147.783437, PnL: -41.965782999999874
# Entry: 2022-12-30T09:00:00+05:30, Price: 1155.295971, Entry_type: 1, Entry_Cond: 1
# Exit: 2022-12-30T11:00:00+05:30, Price: 1167.052745, PnL: 11.75677399999995
# Entry: 2023-01-02T09:00:00+05:30, Price: 1157.520225, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-01-02T15:00:00+05:30, Price: 1169.276999, PnL: 11.75677399999995
# Entry: 2023-01-09T09:00:00+05:30, Price: 1155.386757, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-01-09T11:00:00+05:30, Price: 1175.654709, PnL: 20.267951999999923
# Entry: 2023-01-13T13:00:00+05:30, Price: 1119.299361, Entry_type: 1, Entry_Cond: 3
# Exit: 2023-01-17T15:00:00+05:30, Price: 1125.200445, PnL: 5.901083999999855
# Entry: 2023-01-30T11:00:00+05:30, Price: 1062.535477, Entry_type: 1, Entry_Cond: 2
# Exit: 2023-02-08T11:00:00+05:30, Price: 1065.80377, PnL: 3.268293000000085
# Entry: 2023-02-09T09:00:00+05:30, Price: 1068.300382, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-02-14T11:00:00+05:30, Price: 1077.696723, PnL: 9.39634100000012
# Entry: 2023-02-22T09:00:00+05:30, Price: 1101.210271, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-02-22T11:00:00+05:30, Price: 1088.046315, PnL: 13.163955999999871
# Entry: 2023-02-22T13:00:00+05:30, Price: 1088.069012, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-02-22T15:00:00+05:30, Price: 1079.852888, PnL: 8.216124000000036
# Entry: 2023-03-03T09:00:00+05:30, Price: 1066.348485, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-03-03T11:00:00+05:30, Price: 1076.902346, PnL: 10.553861000000097
# Entry: 2023-03-21T09:00:00+05:30, Price: 1007.246864, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-03-31T09:00:00+05:30, Price: 1047.147267, PnL: 39.9004030000001
# Entry: 2023-04-18T09:00:00+05:30, Price: 1078.990422, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-05-02T09:00:00+05:30, Price: 1104.183509, PnL: -25.193086999999878
# Entry: 2023-05-05T13:00:00+05:30, Price: 1109.607967, Entry_type: -1, Entry_Cond: 6
# Exit: 2023-05-08T11:00:00+05:30, Price: 1122.091028, PnL: -12.483061000000134
# Entry: 2023-05-11T13:00:00+05:30, Price: 1129.126935, Entry_type: -1, Entry_Cond: 6
# Exit: 2023-05-16T13:00:00+05:30, Price: 1115.304782, PnL: 13.822153000000071
# Entry: 2023-05-17T09:00:00+05:30, Price: 1118.028359, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-05-17T11:00:00+05:30, Price: 1106.521246, PnL: 11.50711299999989
# Entry: 2023-05-19T09:00:00+05:30, Price: 1104.8871, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-05-25T09:00:00+05:30, Price: 1104.637439, PnL: 0.2496609999998327
# Entry: 2023-05-31T15:00:00+05:30, Price: 1126.426054, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-06-01T15:00:00+05:30, Price: 1118.141841, PnL: 8.284212999999909
# Entry: 2023-06-12T09:00:00+05:30, Price: 1123.702478, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-06-12T11:00:00+05:30, Price: 1125.472803, PnL: -1.7703250000001844
# Entry: 2023-06-22T11:00:00+05:30, Price: 1162.581539, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-06-22T15:00:00+05:30, Price: 1150.938248, PnL: 11.64329100000009
# Entry: 2023-06-23T09:00:00+05:30, Price: 1147.942313, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-06-23T11:00:00+05:30, Price: 1147.533776, PnL: 0.4085370000000239
# Entry: 2023-07-05T11:00:00+05:30, Price: 1175.768191, Entry_type: -1, Entry_Cond: 6
# Exit: 2023-07-06T09:00:00+05:30, Price: 1195.21907, PnL: -19.450879000000214
# Entry: 2023-07-21T11:00:00+05:30, Price: 1280.175, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-07-21T13:00:00+05:30, Price: 1264.45, PnL: 15.724999999999909
# Entry: 2023-07-24T09:00:00+05:30, Price: 1240.5, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-08-02T09:00:00+05:30, Price: 1243.2, PnL: -2.7000000000000455
# Entry: 2023-08-02T13:00:00+05:30, Price: 1238.35, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-08-02T15:00:00+05:30, Price: 1243.175, PnL: -4.8250000000000455
# Entry: 2023-08-03T15:00:00+05:30, Price: 1237.95, Entry_type: 1, Entry_Cond: 3
# Exit: 2023-08-04T09:00:00+05:30, Price: 1244.375, PnL: 6.4249999999999545
# Entry: 2023-08-17T11:00:00+05:30, Price: 1283.725, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-08-18T09:00:00+05:30, Price: 1258.975, PnL: 24.75
# Entry: 2023-09-06T09:00:00+05:30, Price: 1210.55, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-09-07T13:00:00+05:30, Price: 1217.0, PnL: 6.4500000000000455
# Entry: 2023-09-11T13:00:00+05:30, Price: 1233.975, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-09-11T15:00:00+05:30, Price: 1237.3, PnL: 3.3250000000000455
# Entry: 2023-09-13T13:00:00+05:30, Price: 1226.825, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-09-20T09:00:00+05:30, Price: 1197.925, PnL: -28.90000000000009
# Entry: 2023-09-25T13:00:00+05:30, Price: 1173.4, Entry_type: 1, Entry_Cond: 2
# Exit: 2023-10-03T09:00:00+05:30, Price: 1161.5, PnL: -11.900000000000091
# Entry: 2023-10-11T09:00:00+05:30, Price: 1157.225, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-10-11T11:00:00+05:30, Price: 1164.775, PnL: 7.550000000000182
# Entry: 2023-10-11T13:00:00+05:30, Price: 1164.725, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-10-11T15:00:00+05:30, Price: 1172.525, PnL: 7.800000000000182
# Entry: 2023-10-12T09:00:00+05:30, Price: 1171.925, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-10-17T15:00:00+05:30, Price: 1177.625, PnL: 5.7000000000000455
# Entry: 2023-10-18T09:00:00+05:30, Price: 1177.625, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-10-18T11:00:00+05:30, Price: 1164.55, PnL: -13.075000000000045
# Entry: 2023-10-30T09:00:00+05:30, Price: 1137.0, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-10-30T11:00:00+05:30, Price: 1161.0, PnL: 24.0
# Entry: 2023-11-02T09:00:00+05:30, Price: 1156.975, Entry_type: 1, Entry_Cond: 1
# Exit: 2023-11-02T11:00:00+05:30, Price: 1158.25, PnL: 1.275000000000091
# Entry: 2023-11-09T09:00:00+05:30, Price: 1167.925, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-11-09T11:00:00+05:30, Price: 1158.575, PnL: 9.349999999999909
# Entry: 2023-11-30T13:00:00+05:30, Price: 1192.375, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-11-30T15:00:00+05:30, Price: 1188.725, PnL: 3.650000000000091
# Entry: 2023-12-12T13:00:00+05:30, Price: 1223.25, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-12-12T15:00:00+05:30, Price: 1212.025, PnL: 11.224999999999909
# Entry: 2023-12-13T09:00:00+05:30, Price: 1211.0, Entry_type: -1, Entry_Cond: 4
# Exit: 2023-12-13T11:00:00+05:30, Price: 1207.95, PnL: 3.0499999999999545
# Entry: 2024-01-09T15:00:00+05:30, Price: 1295.15, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-01-10T13:00:00+05:30, Price: 1321.525, PnL: -26.375
# Entry: 2024-01-20T13:00:00+05:30, Price: 1371.775, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-01-23T09:00:00+05:30, Price: 1339.475, PnL: 32.30000000000018
# Entry: 2024-01-23T13:00:00+05:30, Price: 1326.025, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-01-29T09:00:00+05:30, Price: 1391.85, PnL: -65.82499999999982
# Entry: 2024-02-06T13:00:00+05:30, Price: 1428.825, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-02-13T11:00:00+05:30, Price: 1470.85, PnL: -42.024999999999864
# Entry: 2024-02-16T13:00:00+05:30, Price: 1467.5, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-02-23T09:00:00+05:30, Price: 1487.325, PnL: -19.825000000000045
# Entry: 2024-02-28T11:00:00+05:30, Price: 1472.5, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-02-28T13:00:00+05:30, Price: 1457.95, PnL: 14.549999999999955
# Entry: 2024-02-28T15:00:00+05:30, Price: 1457.95, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-03-04T11:00:00+05:30, Price: 1500.6, PnL: -42.649999999999864
# Entry: 2024-03-07T09:00:00+05:30, Price: 1502.975, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-03-07T15:00:00+05:30, Price: 1478.925, PnL: 24.049999999999955
# Entry: 2024-03-11T13:00:00+05:30, Price: 1473.65, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-03-11T15:00:00+05:30, Price: 1466.6, PnL: 7.050000000000182
# Entry: 2024-03-20T13:00:00+05:30, Price: 1440.675, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-03-20T15:00:00+05:30, Price: 1443.75, PnL: 3.0750000000000455
# Entry: 2024-03-21T09:00:00+05:30, Price: 1452.525, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-03-21T11:00:00+05:30, Price: 1452.425, PnL: -0.10000000000013642
# Entry: 2024-03-28T15:00:00+05:30, Price: 1493.35, Entry_type: -1, Entry_Cond: 6
# Exit: 2024-04-02T09:00:00+05:30, Price: 1475.225, PnL: 18.125
# Entry: 2024-04-03T13:00:00+05:30, Price: 1480.475, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-04-03T15:00:00+05:30, Price: 1471.6, PnL: 8.875
# Entry: 2024-04-12T13:00:00+05:30, Price: 1478.0, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-04-12T15:00:00+05:30, Price: 1467.15, PnL: 10.849999999999909
# Entry: 2024-04-18T15:00:00+05:30, Price: 1469.05, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-04-19T09:00:00+05:30, Price: 1450.2, PnL: 18.84999999999991
# Entry: 2024-04-29T09:00:00+05:30, Price: 1450.0, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-04-30T09:00:00+05:30, Price: 1478.825, PnL: 28.825000000000045
# Entry: 2024-05-14T13:00:00+05:30, Price: 1417.35, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-05-14T15:00:00+05:30, Price: 1420.075, PnL: 2.7250000000001364
# Entry: 2024-05-16T13:00:00+05:30, Price: 1409.3, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-05-17T09:00:00+05:30, Price: 1430.0, PnL: 20.700000000000045
# Entry: 2024-05-17T13:00:00+05:30, Price: 1431.725, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-05-17T15:00:00+05:30, Price: 1435.7, PnL: 3.9750000000001364
# Entry: 2024-05-28T13:00:00+05:30, Price: 1463.925, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-05-29T15:00:00+05:30, Price: 1440.775, PnL: 23.149999999999864
# Entry: 2024-05-31T13:00:00+05:30, Price: 1427.225, Entry_type: 1, Entry_Cond: 2
# Exit: 2024-06-03T09:00:00+05:30, Price: 1476.25, PnL: 49.02500000000009
# Entry: 2024-06-19T09:00:00+05:30, Price: 1487.5, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-06-19T15:00:00+05:30, Price: 1458.65, PnL: 28.84999999999991
# Entry: 2024-06-21T09:00:00+05:30, Price: 1473.625, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-06-21T11:00:00+05:30, Price: 1449.125, PnL: 24.5
# Entry: 2024-07-10T09:00:00+05:30, Price: 1595.0, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-07-18T09:00:00+05:30, Price: 1567.175, PnL: 27.825000000000045
# Entry: 2024-07-19T09:00:00+05:30, Price: 1586.0, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-07-19T11:00:00+05:30, Price: 1558.25, PnL: 27.75
# Entry: 2024-07-19T13:00:00+05:30, Price: 1558.2, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-07-19T15:00:00+05:30, Price: 1555.15, PnL: 3.0499999999999545
# Entry: 2024-07-25T11:00:00+05:30, Price: 1494.3, Entry_type: 1, Entry_Cond: 3
# Exit: 2024-07-26T09:00:00+05:30, Price: 1504.95, PnL: 10.650000000000091
# Entry: 2024-08-01T15:00:00+05:30, Price: 1512.05, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-08-05T09:00:00+05:30, Price: 1453.3, PnL: -58.75
# Entry: 2024-08-09T13:00:00+05:30, Price: 1470.65, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-08-16T09:00:00+05:30, Price: 1463.95, PnL: -6.7000000000000455
# Entry: 2024-08-19T09:00:00+05:30, Price: 1482.5, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-08-19T11:00:00+05:30, Price: 1491.175, PnL: 8.674999999999955
# Entry: 2024-08-20T09:00:00+05:30, Price: 1497.225, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-08-20T11:00:00+05:30, Price: 1501.975, PnL: 4.75
# Entry: 2024-08-28T09:00:00+05:30, Price: 1505.0, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-09-05T13:00:00+05:30, Price: 1497.075, PnL: 7.9249999999999545
# Entry: 2024-09-05T15:00:00+05:30, Price: 1497.075, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-09-06T09:00:00+05:30, Price: 1467.275, PnL: 29.799999999999955
# Entry: 2024-09-12T13:00:00+05:30, Price: 1452.7, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-09-12T15:00:00+05:30, Price: 1479.8, PnL: 27.09999999999991
# Entry: 2024-09-18T09:00:00+05:30, Price: 1470.0, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-09-20T09:00:00+05:30, Price: 1482.75, PnL: 12.75
# Entry: 2024-09-20T13:00:00+05:30, Price: 1490.0, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-09-20T15:00:00+05:30, Price: 1485.925, PnL: -4.0750000000000455
# Entry: 2024-09-30T09:00:00+05:30, Price: 1519.4, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-09-30T11:00:00+05:30, Price: 1487.475, PnL: 31.925000000000182
# Entry: 2024-10-21T09:00:00+05:30, Price: 1367.125, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-10-21T11:00:00+05:30, Price: 1368.4, PnL: 1.275000000000091
# Entry: 2024-10-21T13:00:00+05:30, Price: 1368.375, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-10-21T15:00:00+05:30, Price: 1369.2, PnL: 0.8250000000000455
# Entry: 2024-10-30T09:00:00+05:30, Price: 1335.0, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-11-04T09:00:00+05:30, Price: 1290.45, PnL: -44.549999999999955
# Entry: 2024-11-06T13:00:00+05:30, Price: 1313.4, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-11-08T11:00:00+05:30, Price: 1285.05, PnL: -28.350000000000136
# Entry: 2024-11-19T09:00:00+05:30, Price: 1260.75, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-11-21T09:00:00+05:30, Price: 1226.35, PnL: -34.40000000000009
# Entry: 2024-11-22T13:00:00+05:30, Price: 1242.3, Entry_type: 1, Entry_Cond: 1
# Exit: 2024-11-25T09:00:00+05:30, Price: 1300.0, PnL: 57.700000000000045
# Entry: 2024-12-09T13:00:00+05:30, Price: 1305.5, Entry_type: -1, Entry_Cond: 4
# Exit: 2024-12-09T15:00:00+05:30, Price: 1295.15, PnL: 10.349999999999909
# Entry: 2025-01-01T11:00:00+05:30, Price: 1220.3, Entry_type: 1, Entry_Cond: 1
# Exit: 2025-01-02T09:00:00+05:30, Price: 1225.25, PnL: 4.9500000000000455
# Entry: 2025-01-02T11:00:00+05:30, Price: 1225.25, Entry_type: 1, Entry_Cond: 1
# Exit: 2025-01-02T13:00:00+05:30, Price: 1243.0, PnL: 17.75
# Entry: 2025-01-03T09:00:00+05:30, Price: 1243.9, Entry_type: 1, Entry_Cond: 1
# Exit: 2025-01-03T11:00:00+05:30, Price: 1257.3, PnL: 13.399999999999864
# Entry: 2025-01-07T09:00:00+05:30, Price: 1222.0, Entry_type: 1, Entry_Cond: 1
# Exit: 2025-01-08T09:00:00+05:30, Price: 1264.25, PnL: 42.25
# Entry: 2025-01-08T15:00:00+05:30, Price: 1266.5, Entry_type: -1, Entry_Cond: 6
# Exit: 2025-01-09T09:00:00+05:30, Price: 1252.55, PnL: 13.950000000000045
# Entry: 2025-01-20T11:00:00+05:30, Price: 1309.8, Entry_type: -1, Entry_Cond: 6
# Exit: 2025-01-24T13:00:00+05:30, Price: 1246.1, PnL: 63.700000000000045
# Total PnL: 1262.8712075, Number of Trades: 209, Successful Trades: 159
# (1262.8712075, 209)

# %%
data.iloc[231]
# Out:
# Date                   2020-03-25T09:00:00+05:30
# Open                                  433.372966
# High                                  464.983382
# Low                                   433.125658
# Close                                  451.74118
# Volume                                  22338040
# Support                               393.736291
# Resistance                            465.343102
# RSI                                    53.748966
# MACD_Histogram                          5.791848
# ATR                                    20.086801
# Upper_BB                              462.130083
# Lower_BB                              387.110961
# Middle_BB                             424.620522
# 100_MA                                551.643811
# 50_MA                                 470.847272
# 20_MA                                 424.620522
# Rolling_Volume_Mean                   12941288.0
# Price_Action                       Large Body Up
# Buy_Date                                    None
# Sell_Date                                   None
# Stop_Loss                                   None
# Name: 231, dtype: object

# %%
data.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2020-01-02T11:00:00+05:30  687.223046  691.562171  685.896578  690.190738
# 1  2020-01-02T13:00:00+05:30  690.190738  692.888640  689.313920  690.527976
# 2  2020-01-02T15:00:00+05:30  690.550458  691.472241  689.313920  690.348115
# 3  2020-01-03T09:00:00+05:30  689.313920  691.899410  684.817417  689.021647
# 4  2020-01-03T11:00:00+05:30  689.089095  692.281612  688.504550  691.831962
#
#      Volume  Support  Resistance  RSI  MACD_Histogram  ...  Lower_BB  \
# 0   5276040      NaN         NaN  NaN             NaN  ...       NaN
# 1   4800708      NaN         NaN  NaN             NaN  ...       NaN
# 2   2412036      NaN         NaN  NaN             NaN  ...       NaN
# 3  10272348      NaN         NaN  NaN             NaN  ...       NaN
# 4   4614864      NaN         NaN  NaN             NaN  ...       NaN
#
#    Middle_BB  100_MA  50_MA  20_MA  Rolling_Volume_Mean  Price_Action  \
# 0        NaN     NaN    NaN    NaN                  NaN          None
# 1        NaN     NaN    NaN    NaN                  NaN          None
# 2        NaN     NaN    NaN    NaN                  NaN          None
# 3        NaN     NaN    NaN    NaN                  NaN          None
# 4        NaN     NaN    NaN    NaN                  NaN          None
#
#    Buy_Date Sell_Date Stop_Loss
# 0      None      None      None
# 1      None      None      None
# 2      None      None      None
# 3      None      None      None
# 4      None      None      None
#
# [5 rows x 22 columns]
